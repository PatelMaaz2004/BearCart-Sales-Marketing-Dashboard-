# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
website_sessions = pd.read_csv(r"C:\Users\USER\Downloads\website_sessions.csv")
website_sessions
# Out:
#         website_session_id           created_at  user_id  is_repeat_session  \
# 0                        1  2012-03-19 08:04:16        1                  0
# 1                        2  2012-03-19 08:16:49        2                  0
# 2                        3  2012-03-19 08:26:55        3                  0
# 3                        4  2012-03-19 08:37:33        4                  0
# 4                        5  2012-03-19 09:00:55        5                  0
# ...                    ...                  ...      ...                ...
# 482323              403902  2014-12-25 20:14:44   340578                  0
# 482324              437478  2015-02-05 06:14:57   366374                  0
# 482325              160096  2013-12-02 06:02:37   139857                  0
# 482326              165839  2013-12-11 03:13:02   136249                  1
# 482327               45930  2012-11-23 10:37:23    41795                  0
#
# ...

# %%
website_sessions[website_sessions.duplicated()]
# Out:
#         website_session_id           created_at  user_id  is_repeat_session  \
# 472871              250346  2014-05-19 20:19:29   214747                  0
# 472872               11137  2012-06-14 12:42:06    10443                  0
# 472873              132221  2013-09-23 13:37:30   115614                  0
# 472874              147437  2013-11-06 19:01:26   128501                  0
# 472875               57997  2012-12-17 02:47:14    52867                  0
# ...                    ...                  ...      ...                ...
# 482323              403902  2014-12-25 20:14:44   340578                  0
# 482324              437478  2015-02-05 06:14:57   366374                  0
# 482325              160096  2013-12-02 06:02:37   139857                  0
# 482326              165839  2013-12-11 03:13:02   136249                  1
# 482327               45930  2012-11-23 10:37:23    41795                  0
#
# ...

# %%
unique_counts = pd.DataFrame.from_records([(col, website_sessions[col].nunique()) for col in website_sessions.columns],
                          columns=['Column_Name', 'Num_Unique']).sort_values(by=['Num_Unique'])
unique_counts
# Out:
#           Column_Name  Num_Unique
# 3   is_repeat_session           2
# 7         device_type           2
# 8        http_referer           3
# 5        utm_campaign           4
# 6         utm_content           6
# 4          utm_source          15
# 2             user_id      394318
# 1          created_at      470444
# 0  website_session_id      472871

# %%
website_sessions["utm_campaign"].value_counts()
# Out:
# utm_campaign
# nonbrand            303026
# brand                37088
# desktop_targeted      5035
# pilot                 4562
# Name: count, dtype: int64

# %%
website_sessions["utm_content"].value_counts()
# Out:
# utm_content
# g_ad_1         288391
# b_ad_1          55957
# g_ad_2          33999
# b_ad_2           8095
# social_ad_2      5699
# social_ad_1      5206
# Name: count, dtype: int64

# %%
website_sessions["utm_source"].value_counts()
website_sessions["utm_source"].unique()
# Out:
# array(['gsearch', 'Gsearch', 'GSEARCH', 'gsearch_ads', nan, 'nan_ads',
#        'Bsearch', 'bsearch', 'NAN', 'Nan', 'BSEARCH', 'bsearch_ads',
#        'socialbook', 'socialbook_ads', 'SOCIALBOOK', 'Socialbook'],
#       dtype=object)

# %%
website_sessions.isnull().sum()
# Out:
# website_session_id         0
# created_at                 0
# user_id                    0
# is_repeat_session          0
# utm_source             75560
# utm_campaign          132617
# utm_content            84981
# device_type                0
# http_referer           40724
# dtype: int64

# %%
website_sessions[website_sessions.utm_source.isnull()].describe(include="all")
# Out:
#         website_session_id           created_at        user_id  \
# count         75560.000000                75560   75560.000000
# unique                 NaN                73999            NaN
# top                    NaN  2014-04-12 21:57:31            NaN
# freq                   NaN                    2            NaN
# mean         266202.808020                  NaN  213321.029764
# std          129170.588739                  NaN  103576.326031
# min             905.000000                  NaN      27.000000
# 25%          164069.500000                  NaN  131075.750000
# 50%          274778.000000                  NaN  221263.500000
# 75%          378908.500000                  NaN  299663.500000
# max          472871.000000                  NaN  394318.000000
#
#         is_repeat_session utm_source utm_campaign utm_content device_type  \
# count        75560.000000          0            0           0       75560
# ...

# %%
website_pd_views = pd.read_csv(r"C:\Users\USER\Downloads\website_pageviews.csv")
website_pd_views
# Out:
#          website_pageview_id           created_at  website_session_id  \
# 0                          1  2012-03-19 08:04:16                   1
# 1                          2  2012-03-19 08:16:49                   2
# 2                          3  2012-03-19 08:26:55                   3
# 3                          4  2012-03-19 08:37:33                   4
# 4                          5  2012-03-19 09:00:55                   5
# ...                      ...                  ...                 ...
# 1188119              1188120  2015-03-19 07:57:32              472866
# 1188120              1188121  2015-03-19 07:58:13              472870
# 1188121              1188122  2015-03-19 07:59:07              472866
# 1188122              1188123  2015-03-19 07:59:08              472871
# 1188123              1188124  2015-03-19 07:59:32              472868
#
#                    pageview_url
# 0                         /home
# 1                         /home
# ...

# %%
website_sessions["website_session_id"].value_counts()
# Out:
# website_session_id
# 98313     2
# 215820    2
# 201002    2
# 38702     2
# 50132     2
#          ..
# 472867    1
# 472868    1
# 472869    1
# 472870    1
# 3         1
# Name: count, Length: 472871, dtype: int64

# %%
website_sessions[website_sessions["website_session_id"]==38702]
# Out:
#         website_session_id           created_at  user_id  is_repeat_session  \
# 38701                38702  2012-11-01 22:41:49    28648                  1
# 479210               38702  2012-11-01 22:41:49    28648                  1
#
#        utm_source utm_campaign utm_content device_type http_referer
# 38701         NaN          NaN         NaN      mobile          NaN
# 479210        NaN          NaN         NaN      mobile          NaN

# %%
website_sessions.duplicated().sum()
# Out:
# np.int64(9457)

# %%
print(f'Duplicates in records data: {website_sessions.duplicated().sum()}, ({np.round(100*website_sessions.duplicated().sum()/len(website_sessions),1)}%)')
# Out:
# Duplicates in records data: 9457, (2.0%)

# %%
website_sessions.drop_duplicates(keep="first",inplace=True)

# %%
website_sessions
# Out:
#         website_session_id           created_at  user_id  is_repeat_session  \
# 0                        1  2012-03-19 08:04:16        1                  0
# 1                        2  2012-03-19 08:16:49        2                  0
# 2                        3  2012-03-19 08:26:55        3                  0
# 3                        4  2012-03-19 08:37:33        4                  0
# 4                        5  2012-03-19 09:00:55        5                  0
# ...                    ...                  ...      ...                ...
# 472866              472867  2015-03-19 07:49:25   394314                  0
# 472867              472868  2015-03-19 07:54:36   394315                  0
# 472868              472869  2015-03-19 07:55:40   394316                  0
# 472869              472870  2015-03-19 07:56:29   394317                  0
# 472870              472871  2015-03-19 07:59:08   394318                  0
#
# ...

# %%
unique_counts = pd.DataFrame.from_records([(col, website_sessions[col].nunique()) for col in website_sessions.columns],
                          columns=['Column_Name', 'Num_Unique']).sort_values(by=['Num_Unique'])
unique_counts
# Out:
#           Column_Name  Num_Unique
# 3   is_repeat_session           2
# 7         device_type           2
# 8        http_referer           3
# 5        utm_campaign           4
# 6         utm_content           6
# 4          utm_source          15
# 2             user_id      394318
# 1          created_at      470444
# 0  website_session_id      472871

# %%
website_sessions.user_id.value_counts()
# Out:
# user_id
# 178119    4
# 73051     4
# 192234    4
# 180820    4
# 132198    4
#          ..
# 394314    1
# 394315    1
# 394316    1
# 394317    1
# 4         1
# Name: count, Length: 394318, dtype: int64

# %%
website_sessions[website_sessions["user_id"]==192234]
# Out:
#         website_session_id           created_at  user_id  is_repeat_session  \
# 222886              222887  2014-04-02 10:59:26   192234                  0
# 243325              243326  2014-05-07 21:05:23   192234                  1
# 246860              246861  2014-05-14 01:01:54   192234                  1
# 250866              250867  2014-05-20 16:06:35   192234                  1
#
#        utm_source utm_campaign utm_content device_type  \
# 222886    gsearch     nonbrand      g_ad_1     desktop
# 243325        NaN          NaN         NaN     desktop
# 246860    bsearch        brand      b_ad_2     desktop
# 250866        Nan          NaN         NaN      mobile
#
#                    http_referer
# 222886  https://www.gsearch.com
# 243325  https://www.bsearch.com
# 246860  https://www.bsearch.com
# 250866  https://www.gsearch.com

# %%
repeat_users = (
    website_sessions['user_id']
    .value_counts()
    .loc[lambda x: x > 1]
    .index
)

# %%
repeat_users
# Out:
# Index([178119,  73051, 192234, 180820, 132198, 110048, 185033,  44812,  95602,
#        141242,
#        ...
#        390985, 391016, 391079, 391087, 391226, 391234, 391263, 391403, 391407,
#        391434],
#       dtype='int64', name='user_id', length=51270)

# %%
len(website_sessions)
# Out:
# 472871

# %%
472871 - 51270
# Out:
# 421601

# %%
website_sessions.user_id.nunique()
# Out:
# 394318

# %%
website_sessions.columns
# Out:
# Index(['website_session_id', 'created_at', 'user_id', 'is_repeat_session',
#        'utm_source', 'utm_campaign', 'utm_content', 'device_type',
#        'http_referer'],
#       dtype='object')

# %%
website_sessions["created_at"] = pd.to_datetime(website_sessions["created_at"])

# %%
website_sessions
# Out:
#         website_session_id          created_at  user_id  is_repeat_session  \
# 0                        1 2012-03-19 08:04:16        1                  0
# 1                        2 2012-03-19 08:16:49        2                  0
# 2                        3 2012-03-19 08:26:55        3                  0
# 3                        4 2012-03-19 08:37:33        4                  0
# 4                        5 2012-03-19 09:00:55        5                  0
# ...                    ...                 ...      ...                ...
# 472866              472867 2015-03-19 07:49:25   394314                  0
# 472867              472868 2015-03-19 07:54:36   394315                  0
# 472868              472869 2015-03-19 07:55:40   394316                  0
# 472869              472870 2015-03-19 07:56:29   394317                  0
# 472870              472871 2015-03-19 07:59:08   394318                  0
#
#        utm_source utm_campaign utm_content device_type  \
# ...

# %%
user_sessions = (
    website_sessions.groupby('user_id')['website_session_id']
      .nunique()
      .reset_index(name='session_count')
)

# %%
user_sessions.describe()
# Out:
#             user_id  session_count
# count  394318.00000  394318.000000
# mean   197159.50000       1.199212
# std    113829.94606       0.604871
# min         1.00000       1.000000
# 25%     98580.25000       1.000000
# 50%    197159.50000       1.000000
# 75%    295738.75000       1.000000
# max    394318.00000       4.000000

# %%
repeat_users = user_sessions[user_sessions['session_count'] > 1]

# %%
repeat_users
# Out:
#         user_id  session_count
# 12           13              2
# 16           17              2
# 26           27              2
# 35           36              2
# 42           43              2
# ...         ...            ...
# 391233   391234              2
# 391262   391263              2
# 391402   391403              2
# 391406   391407              2
# 391433   391434              2
#
# [51270 rows x 2 columns]

# %%
repeat_sessions = website_sessions[website_sessions['is_repeat_session'] == 1]
repeat_sessions
# Out:
#         website_session_id          created_at  user_id  is_repeat_session  \
# 966                    967 2012-03-25 23:06:28      489                  1
# 978                    979 2012-03-26 02:40:21      604                  1
# 1044                  1045 2012-03-26 11:54:49      846                  1
# 1050                  1051 2012-03-26 12:48:41      152                  1
# 1174                  1175 2012-03-27 09:31:58      218                  1
# ...                    ...                 ...      ...                ...
# 472846              472847 2015-03-19 06:57:13   378178                  1
# 472852              472853 2015-03-19 07:28:48   331346                  1
# 472853              472854 2015-03-19 07:29:55   370617                  1
# 472859              472860 2015-03-19 07:37:38   365493                  1
# 472860              472861 2015-03-19 07:38:28   383375                  1
#
#        utm_source utm_campaign utm_content device_type  \
# ...

# %%
website_pd_views
# Out:
#          website_pageview_id           created_at  website_session_id  \
# 0                          1  2012-03-19 08:04:16                   1
# 1                          2  2012-03-19 08:16:49                   2
# 2                          3  2012-03-19 08:26:55                   3
# 3                          4  2012-03-19 08:37:33                   4
# 4                          5  2012-03-19 09:00:55                   5
# ...                      ...                  ...                 ...
# 1188119              1188120  2015-03-19 07:57:32              472866
# 1188120              1188121  2015-03-19 07:58:13              472870
# 1188121              1188122  2015-03-19 07:59:07              472866
# 1188122              1188123  2015-03-19 07:59:08              472871
# 1188123              1188124  2015-03-19 07:59:32              472868
#
#                    pageview_url
# 0                         /home
# 1                         /home
# ...

# %%
orders = pd.read_csv(r"C:\Users\USER\Downloads\orders.csv")
orders
# Out:
#        order_id           created_at  website_session_id   user_id  \
# 0             1  2012-03-19 10:42:46                  20      20.0
# 1             2  2012-03-19 19:27:37                 104     104.0
# 2             3  2012-03-20 06:44:45                 147     147.0
# 3             4  2012-03-20 09:41:45                 160     160.0
# 4             5  2012-03-20 11:28:15                 177     177.0
# ...         ...                  ...                 ...       ...
# 32308     32309  2015-03-19 03:58:12              472795  394255.0
# 32309     32310  2015-03-19 04:10:43              472798  394257.0
# 32310     32311  2015-03-19 05:27:28              472809  394268.0
# 32311     32312  2015-03-19 05:35:57              472814  394273.0
# 32312     32313  2015-03-19 05:38:31              472818  386000.0
#
#        primary_product_id  items_purchased  price_usd  cogs_usd
# 0                       1                1      49.99     19.49
# ...

# %%
orders
# Out:
#        order_id           created_at  website_session_id   user_id  \
# 0             1  2012-03-19 10:42:46                  20      20.0
# 1             2  2012-03-19 19:27:37                 104     104.0
# 2             3  2012-03-20 06:44:45                 147     147.0
# 3             4  2012-03-20 09:41:45                 160     160.0
# 4             5  2012-03-20 11:28:15                 177     177.0
# ...         ...                  ...                 ...       ...
# 32308     32309  2015-03-19 03:58:12              472795  394255.0
# 32309     32310  2015-03-19 04:10:43              472798  394257.0
# 32310     32311  2015-03-19 05:27:28              472809  394268.0
# 32311     32312  2015-03-19 05:35:57              472814  394273.0
# 32312     32313  2015-03-19 05:38:31              472818  386000.0
#
#        primary_product_id  items_purchased  price_usd  cogs_usd
# 0                       1                1      49.99     19.49
# ...

# %%
orders.isnull().sum()
# Out:
# order_id                 0
# created_at               0
# website_session_id       0
# user_id               1616
# primary_product_id       0
# items_purchased          0
# price_usd                0
# cogs_usd                 0
# dtype: int64

# %%
unique_counts = pd.DataFrame.from_records([(col, orders[col].nunique()) for col in orders.columns],
                          columns=['Column_Name', 'Num_Unique']).sort_values(by=['Num_Unique'])
unique_counts
# Out:
#           Column_Name  Num_Unique
# 5     items_purchased           2
# 4  primary_product_id           4
# 7            cogs_usd          10
# 6           price_usd          20
# 3             user_id       30123
# 1          created_at       32299
# 2  website_session_id       32313
# 0            order_id       32313

# %%
website_sessions["user_id"].nunique()
# Out:
# 394318

# %%
orders[orders["user_id"].isnull()]
# Out:
#        order_id           created_at  website_session_id  user_id  \
# 45           46  2012-03-29 16:11:05                1581      NaN
# 56           57  2012-03-31 02:32:43                1802      NaN
# 66           67  2012-04-02 17:17:42                2102      NaN
# 97           98  2012-04-09 15:01:23                3247      NaN
# 140         141  2012-04-22 16:58:22                4815      NaN
# ...         ...                  ...                 ...      ...
# 32238     32239  2015-03-18 02:57:01              471758      NaN
# 32255     32256  2015-03-18 10:51:31              471959      NaN
# 32259     32260  2015-03-18 12:03:15              472054      NaN
# 32287     32288  2015-03-18 18:10:53              472479      NaN
# 32300     32301  2015-03-18 23:53:53              472709      NaN
#
#        primary_product_id  items_purchased  price_usd  cogs_usd
# 45                      1                1  49.990000     19.49
# ...

# %%
website_sessions[website_sessions["website_session_id"]==1581]
# Out:
#       website_session_id          created_at  user_id  is_repeat_session  \
# 1580                1581 2012-03-29 15:51:13     1574                  0
#
#      utm_source utm_campaign utm_content device_type             http_referer
# 1580    gsearch     nonbrand      g_ad_1     desktop  https://www.gsearch.com

# %%
new = pd.merge(orders,website_sessions[["user_id","website_session_id"]],on="website_session_id",how="inner")

# %%
new[new["user_id_x"].isnull()]
# Out:
#        order_id           created_at  website_session_id  user_id_x  \
# 45           46  2012-03-29 16:11:05                1581        NaN
# 56           57  2012-03-31 02:32:43                1802        NaN
# 66           67  2012-04-02 17:17:42                2102        NaN
# 97           98  2012-04-09 15:01:23                3247        NaN
# 140         141  2012-04-22 16:58:22                4815        NaN
# ...         ...                  ...                 ...        ...
# 32238     32239  2015-03-18 02:57:01              471758        NaN
# 32255     32256  2015-03-18 10:51:31              471959        NaN
# 32259     32260  2015-03-18 12:03:15              472054        NaN
# 32287     32288  2015-03-18 18:10:53              472479        NaN
# 32300     32301  2015-03-18 23:53:53              472709        NaN
#
#        primary_product_id  items_purchased  price_usd  cogs_usd  user_id_y
# 45                      1                1  49.990000     19.49       1574
# ...

# %%
new
# Out:
#        order_id           created_at  website_session_id  user_id_x  \
# 0             1  2012-03-19 10:42:46                  20       20.0
# 1             2  2012-03-19 19:27:37                 104      104.0
# 2             3  2012-03-20 06:44:45                 147      147.0
# 3             4  2012-03-20 09:41:45                 160      160.0
# 4             5  2012-03-20 11:28:15                 177      177.0
# ...         ...                  ...                 ...        ...
# 32308     32309  2015-03-19 03:58:12              472795   394255.0
# 32309     32310  2015-03-19 04:10:43              472798   394257.0
# 32310     32311  2015-03-19 05:27:28              472809   394268.0
# 32311     32312  2015-03-19 05:35:57              472814   394273.0
# 32312     32313  2015-03-19 05:38:31              472818   386000.0
#
#        primary_product_id  items_purchased  price_usd  cogs_usd  user_id_y
# 0                       1                1      49.99     19.49         20
# ...

# %%
order_items = pd.read_csv(r"C:\Users\USER\Downloads\order_items.csv")
order_items
# Out:
#        order_item_id           created_at  order_id  product_id  \
# 0                  1  2012-03-19 10:42:46         1           1
# 1                  2  2012-03-19 19:27:37         2           1
# 2                  3  2012-03-20 06:44:45         3           1
# 3                  4  2012-03-20 09:41:45         4           1
# 4                  5  2012-03-20 11:28:15         5           1
# ...              ...                  ...       ...         ...
# 40020          40021  2015-03-19 04:10:43     32310           4
# 40021          40022  2015-03-19 05:27:28     32311           2
# 40022          40023  2015-03-19 05:27:28     32311           4
# 40023          40024  2015-03-19 05:35:57     32312           4
# 40024          40025  2015-03-19 05:38:31     32313           1
#
#        is_primary_item  price_usd  cogs_usd
# 0                    1      49.99     19.49
# 1                    1      49.99     19.49
# 2                    1      49.99     19.49
# ...

# %%
order_refunds = pd.read_csv(r"C:\Users\USER\Downloads\order_item_refunds.csv")
order_refunds
# Out:
#       order_item_refund_id           created_at  order_item_id  order_id  \
# 0                        1  2012-04-06 11:32:43             57        57
# 1                        2  2012-04-13 01:09:43             74        74
# 2                        3  2012-04-15 07:03:48             71        71
# 3                        4  2012-04-17 20:00:37            118       118
# 4                        5  2012-04-22 20:53:49            116       116
# ...                    ...                  ...            ...       ...
# 1726                  1727  2015-03-30 09:37:23          39950     32255
# 1727                  1728  2015-03-30 21:33:51          39671     32049
# 1728                  1729  2015-03-31 19:59:48          39729     32090
# 1729                  1730  2015-04-01 03:54:48          39717     32079
# 1730                  1731  2015-04-01 18:11:08          39947     32252
#
#       refund_amount_usd
# 0                 49.99
# 1                 49.99
# ...
